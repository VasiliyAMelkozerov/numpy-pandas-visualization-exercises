# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import seaborn as sns

# %% [markdown]
# # Use the iris database to answer the following quesitons:

# %% [markdown]
# ## 1 What does the distribution of petal lengths look like?

# %%
iris = sns.load_dataset('iris')
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
sns.displot(iris.petal_length, kde=True)

# %%
iris.petal_length.dtype
# Out:
# dtype('float64')

# %%
iris.species.unique()
# Out:
# array(['setosa', 'versicolor', 'virginica'], dtype=object)

# %%
sns.displot(data = iris, x='petal_length')

# %% [markdown]
# ## 2 Is there a correlation between petal length and petal width? Use http://guessthecorrelation.com/ as a hint to how we could visually determine if a correlation exists between two numeric columns.

# %%
sns.relplot(data = iris, 
            x="petal_length", 
            y="petal_width",
            hue ="species")

# %%
sns.pairplot(data = iris, corner=True)

# %%
sns.heatmap(iris.corr(), 
            annot=True, 
#             fmt='0.01f',
           cmap='Blues')
# Out:
# <AxesSubplot:>

# %%
sns.heatmap(iris.corr(), 
            annot=True, 
            fmt="0.3f",
           cmap='Blues')
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### we can say that petal width and sepal length have a strong correlation to petal length

# %% [markdown]
# ## 3 Would it be reasonable to predict species based on sepal width and sepal length? For this, you'll visualize two numeric columns through the lense of a categorical column.

# %%
sns.relplot(data = iris, 
            x = "sepal_length", 
            y = "sepal_width",
           hue="species")

# %%
sns.catplot(data=iris)
sns.catplot(data = iris, x = 'sepal_length', y ='sepal_width', hue='species')
# sns.catplot(data = iris, x ='sepal_width', y = 'sepal_length')

# %%
sns.pairplot(data = iris, hue="species")

# %% [markdown]
# ### yes it would be reasonable to predict species based on sepal width and sepal length

# %% [markdown]
# ## 4 Which features would be best used to predict species?

# %% [markdown]
# #### petal width and length

# %%
# sns.regplot(data=iris, y="petal_width", x="species")

# %%
# sns.regplot(data=iris, y="sepal_length", x="species")

# %%
# sns.regplot(data=iris, y="petal_length", x="species")

# %%
# sns.regplot(data=iris, y="sepal_width", x="species")

# %% [markdown]
# # ___________________________________________________

# %% [markdown]
# ## 1 Using the lesson as an example, use seaborn's load_dataset function to load the anscombe data set. Use pandas to group the data by the dataset column, and calculate summary statistics for each dataset. What do you notice?

# %%
df = sns.load_dataset('anscombe')
# ans = anscombe
df.head()
# Out:
#   dataset     x     y
# 0       I  10.0  8.04
# 1       I   8.0  6.95
# 2       I  13.0  7.58
# 3       I   9.0  8.81
# 4       I  11.0  8.33

# %%
df.shape
# Out:
# (44, 3)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 44 entries, 0 to 43
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   dataset  44 non-null     object
#  1   x        44 non-null     float64
#  2   y        44 non-null     float64
# dtypes: float64(2), object(1)
# memory usage: 1.2+ KB

# %%
df.describe().T
# Out:
#    count      mean       std  min     25%   50%      75%    max
# x   44.0  9.000000  3.198837  4.0  7.0000  8.00  11.0000  19.00
# y   44.0  7.500682  1.958925  3.1  6.1175  7.52   8.7475  12.74

# %%
# df.groupby('dataset').x.mean()
df.groupby("dataset")[['x','y']].agg(["mean", 'median'])
# Out:
#            x                y
#         mean median      mean median
# dataset
# I        9.0    9.0  7.500909   7.58
# II       9.0    9.0  7.500909   8.14
# III      9.0    9.0  7.500000   7.11
# IV       9.0    8.0  7.500909   7.04

# %%
df.groupby('dataset').describe()
# Out:
#             x                                               y            \
#         count mean       std  min  25%  50%   75%   max count      mean
# dataset
# I        11.0  9.0  3.316625  4.0  6.5  9.0  11.5  14.0  11.0  7.500909
# II       11.0  9.0  3.316625  4.0  6.5  9.0  11.5  14.0  11.0  7.500909
# III      11.0  9.0  3.316625  4.0  6.5  9.0  11.5  14.0  11.0  7.500000
# IV       11.0  9.0  3.316625  8.0  8.0  8.0   8.0  19.0  11.0  7.500909
#
#
#               std   min    25%   50%   75%    max
# dataset
# I        2.031568  4.26  6.315  7.58  8.57  10.84
# II       2.031657  3.10  6.695  8.14  8.95   9.26
# III      2.030424  5.39  6.250  7.11  7.98  12.74
# IV       2.030579  5.25  6.170  7.04  8.19  12.50

# %%
df.groupby('dataset').x.median()
# Out:
# dataset
# I      9.0
# II     9.0
# III    9.0
# IV     8.0
# Name: x, dtype: float64

# %%
df.groupby('dataset').y.mean()
# Out:
# dataset
# I      7.500909
# II     7.500909
# III    7.500000
# IV     7.500909
# Name: y, dtype: float64

# %%
df.groupby('dataset').y.median()
# Out:
# dataset
# I      7.58
# II     8.14
# III    7.11
# IV     7.04
# Name: y, dtype: float64

# %% [markdown]
# # -------------------------------------------------

# %%
#relplot for x vs y
sns.relplot(data = df, x='x', y='y', col = 'dataset')

# %%
#reviewed code
sns.lmplot(data = df, 
           x='x',
           y='y', 
           col='dataset',
           ci =0)

# %%
# ancom = ans.groupby('dataset')
sns.relplot(data=df, x='x', y='y', hue='dataset')

# %%
sns.displot(data=df, x='x', y='y', hue='dataset')

# %%
sns.catplot(data=df, x='x', y='y', hue='dataset')

# %%
# InsectSprays
InsectSprays = data('InsectSprays')
data('InsectSprays', show_doc = True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/cs/9mn89l_n6p3c9sq01q5f54kh0000gn/T/ipykernel_73664/1567407320.py in <module>
#       1 # InsectSprays
# ----> 2 InsectSprays = data('InsectSprays')
#       3 data('InsectSprays', show_doc = True)
#
# NameError: name 'data' is not defined

# %%
swiss = data('swiss')
data('swiss', show_doc=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/cs/9mn89l_n6p3c9sq01q5f54kh0000gn/T/ipykernel_73664/1825419873.py in <module>
# ----> 1 swiss = data('swiss')
#       2 data('swiss', show_doc=True)
#
# NameError: name 'data' is not defined

# %%
swiss.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/cs/9mn89l_n6p3c9sq01q5f54kh0000gn/T/ipykernel_73664/3269853618.py in <module>
# ----> 1 swiss.head()
#
# NameError: name 'swiss' is not defined

# %%
swiss['is_catholic'] =

# %%
sns. boxplot(x='is_catholic', y='Fertility', data='swiss')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/cs/9mn89l_n6p3c9sq01q5f54kh0000gn/T/ipykernel_73664/1338204312.py in <module>
# ----> 1 sns. boxplot(x='is_catholic', y='Fertility', data='swiss')
#
# /usr/local/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# /usr/local/anaconda3/lib/python3.9/site-packages/seaborn/categorical.py in boxplot(x, y, hue, data, order, hue_order, orient, color, palette, saturation, width, dodge, fliersize, linewidth, whis, ax, **kwargs)
#    2241 ):
#    2242
# -> 2243     plotter = _BoxPlotter(x, y, hue, data, order, hue_order,
#    2244                           orient, color, palette, saturation,
# ...

# %%
swiss.groupby('is_catholic').Fertility.mean()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/cs/9mn89l_n6p3c9sq01q5f54kh0000gn/T/ipykernel_73664/3661313699.py in <module>
# ----> 1 swiss.groupby('is_catholic').Fertility.mean()
#
# NameError: name 'swiss' is not defined

# %%
sns.pairplot(data = swiss.iloc[:,:-1])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/cs/9mn89l_n6p3c9sq01q5f54kh0000gn/T/ipykernel_73664/1283245741.py in <module>
# ----> 1 sns.pairplot(data = swiss.iloc[:,:1])
#
# NameError: name 'swiss' is not defined

# %%
swiss.corr().Fertility
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/cs/9mn89l_n6p3c9sq01q5f54kh0000gn/T/ipykernel_73664/2345806990.py in <module>
# ----> 1 swiss.corr().Fertility
#
# NameError: name 'swiss' is not defined

# %%
def get_db_url(db):
    from env import user, password, host
    return f'"mysql+pymysql://{user}:{password}@{host}/{db}"
# Out:
#   File "/var/folders/cs/9mn89l_n6p3c9sq01q5f54kh0000gn/T/ipykernel_73664/4015350874.py", line 3
#     return f'"mysql+pymysql://{user}:{password}@{host}/{db}"
#                                                             ^
# SyntaxError: EOL while scanning string literal

# %%
# url= get_db_url

# %%
import seaborn as sns

df = sns.load_dataset('tips')
df.to_clipboard()

# %%
import seaborn as sns

df = sns.load_dataset('Table5_Dates')
df.to_clipboard()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/cs/9mn89l_n6p3c9sq01q5f54kh0000gn/T/ipykernel_75384/444374694.py in <module>
#       1 import seaborn as sns
#       2
# ----> 3 df = sns.load_dataset('Table5_Dates')
#       4 df.to_clipboard()
#
# /usr/local/anaconda3/lib/python3.9/site-packages/seaborn/utils.py in load_dataset(name, cache, data_home, **kws)
#     593         if not os.path.exists(cache_path):
#     594             if name not in get_dataset_names():
# --> 595                 raise ValueError(f"'{name}' is not one of the example datasets.")
#     596             urlretrieve(url, cache_path)
#     597         full_path = cache_path
#
# ValueError: 'Table5_Dates' is not one of the example datasets.
